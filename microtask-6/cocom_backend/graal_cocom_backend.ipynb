# %% [markdown]
# ## Microtask #6: CoCom Backend
#
# > To create a Python script to execute Graal via its Python interface using the CoCom Backend.
#
# **What is [Graal](https://github.com/chaoss/grimoirelab-graal)?**
#    - Graal [ Generic Repository AnALyzer ] with the help of Perceval's Git Backend fetches the commits from a Git repository and provides a mechanism to plug third party tools/libraries focused on source code analysis.
#
#
# **What Graal's [CoCom](https://github.com/chaoss/grimoirelab-graal/blob/master/graal/backends/core/cocom.py) Backend does?**
#
#   - CoCom ( Code Complexity ) Backend based on supported languages with the help of [Lizard](https://github.com/terryyin/lizard) helps us with various source code analysis such as:
#    - Cyclomatic Complexity and Average Cyclomatic Complexity
#    - Lines of Code and Average Lines of Code
#    - Number of functions
#       ... and many more
#
# **We'll start off by importing required modules**

# %%
from graal.backends.core.cocom import CoCom, FileAnalyzer
from pprint import pprint
from datetime import datetime
import os

# %% [markdown]
# - The `CoCom` ( Code Complexity ) backend requires two mandatory arguments :

# %%
# URL for the git repo to analyze
REPOSITORY_URL = "http://github.com/inishchith/MeetInTheMiddle"

# directory where to mirror the repo
REPO_DIR = "MeetInTheMiddle"

# %%
# Cocom object initialization
cocom = CoCom(uri=REPOSITORY_URL, git_path=REPO_DIR)

# %% [markdown]
# **We'll now try to [fetch()](https://github.com/chaoss/grimoirelab-graal/blob/b288279e76126021f2b973a36e9def4179623d36/graal/backends/core/cocom.py#L85) commits and analyze them from the git repository**
#
# - The fetch() method returns a generator, we'll convert it to a list for our convenience

# %%
from_date = datetime(2018, 12, 12)
to_date = datetime(2018, 12, 30)

# fetch all commits within range from_date <= date <= to_date
# uses perceval backend to fetch commits and performs analysis on the file present in worktreepath
commits = list(cocom.fetch(from_date=from_date, to_date=to_date))

n_commits = len(commits)
print("Number of commits: ", n_commits)
# Out:
# Number of commits:  14

# %% [markdown]
# **Let's check the structure of one of the commits. ( picking 1st one in this case )**

# %%
first_commit = commits[0]
pprint(first_commit)
# Out:
# {'backend_name': 'CoCom',
#  'backend_version': '0.2.3',
#  'category': 'code_complexity',
#  'data': {'Author': 'inishchith <inishchith@gmail.com>',
#           'AuthorDate': 'Wed Dec 12 15:00:07 2018 +0530',
#           'Commit': 'inishchith <inishchith@gmail.com>',
#           'CommitDate': 'Wed Dec 12 15:00:07 2018 +0530',
#           'analysis': [{'blanks': 17,
#                         'comments': 1,
#                         'ext': 'html',
#                         'file_path': 'MeetMe.html',
#                         'loc': 89},
#                        {'blanks': 0,
#                         'comments': 0,
#                         'ext': 'md',
#                         'file_path': 'api/README.md',
#                         'loc': 1},
#                        {'avg_ccn': 0,
#                         'avg_loc': 0,
#                         'avg_tokens': 0,
#                         'blanks': 0,
#                         'ccn': 0,
#                         'comments': 1,
#                         'ext': 'js',
#                         'file_path': 'api/routes/api.js',
#                         'loc': 0,
#                         'num_funs': 0,
#                         'tokens': 0},
#                        {'avg_ccn': 1.7666666666666666,
#                         'avg_loc': 13.266666666666667,
#                         'avg_tokens': 78.83333333333333,
#                         'blanks': 81,
#                         'ccn': 53,
#                         'comments': 19,
#                         'ext': 'js',
#                         'file_path': 'app.js',
#                         'loc': 381,
#                         'num_funs': 30,
#                         'tokens': 2406},
#                        {'blanks': 0,
#                         'comments': 0,
#                         'ext': 'png',
#                         'file_path': 'assets/icons/centroid.png',
#                         'loc': 0},
#                        {'blanks': 0,
#                         'comments': 0,
#                         'ext': 'png',
#                         'file_path': 'assets/icons/google-maps.png',
#                         'loc': 0},
#                        {'blanks': 0,
#                         'comments': 0,
#                         'ext': 'png',
#                         'file_path': 'assets/icons/map-2.png',
#                         'loc': 0},
#                        {'blanks': 0,
#                         'comments': 0,
#                         'ext': 'png',
#                         'file_path': 'assets/icons/map.png',
#                         'loc': 0},
#                        {'blanks': 0,
#                         'comments': 0,
#                         'ext': 'png',
#                         'file_path': 'assets/icons/marker.png',
#                         'loc': 0},
#                        {'blanks': 34,
#                         'comments': 9,
#                         'ext': 'css',
#                         'file_path': 'assets/style.css',
#                         'loc': 126},
#                        {'blanks': 18,
#                         'comments': 3,
#                         'ext': 'html',
#                         'file_path': 'index.html',
#                         'loc': 96}],
#           'commit': '16e1762ac2319cf9a654b272ebda090c245363b5',
#           'message': ' Viewing Changes'},
#  'graal_version': '0.1.0',
#  'origin': 'http://github.com/inishchith/MeetInTheMiddle',
#  'tag': 'http://github.com/inishchith/MeetInTheMiddle',
#  'timestamp': 1552840035.90758,
#  'updated_on': 1544607007.0,
#  'uuid': '376bf6a5c1521ea5a819fc7681e7a3f084cec737'}

# %% [markdown]
# **Graal depends on Lizard in order to provide source code related analysis.**
#
# - Note: Graal now supports Lua & GoLang. [REF](https://github.com/chaoss/grimoirelab-graal/pull/9)

# %% [markdown]
# **Let us now print out some useful information from all the fetched commits**

# %%
# Check analysis attribute i.e analysis produced by graal via lizard
print("-"*100)
for commit in commits:
    print("Commit Message:",commit['data']['message'])
    for change in commit['data']['analysis']:
        if change["ext"] in FileAnalyzer.ALLOWED_EXTENSIONS:
            print("File Name: ",change["file_path"])
            print("\tAverage Cyclomatic Complexity (ccn): ",change["avg_ccn"])
            print("\tAverage Lines of code: ",change["avg_loc"])
            print("\tAverage Tokens: ",change["avg_tokens"])
            print("\tBlanks: ",change["blanks"])
            print("\tCyclomatic Complexity (ccn): ",change["ccn"])
            print("\tNumber of Comments: ",change["comments"])
            print("\tExtension: ",change["ext"])
            print("\tLines of code: ",change["loc"])
            print("\tNumber of functions: ",change["num_funs"])
            print("\tTokens: ",change["tokens"])
        else:
            print("\t* Analysis cannot be performed for: ", change["file_path"])
        print()
    print("-"*100)
# Out:
# ----------------------------------------------------------------------------------------------------
# Commit Message:  Viewing Changes
# 	* Analysis cannot be performed for:  MeetMe.html
#
# 	* Analysis cannot be performed for:  api/README.md
#
# File Name:  api/routes/api.js
# 	Average Cyclomatic Complexity (ccn):  0
# 	Average Lines of code:  0
# 	Average Tokens:  0
# 	Blanks:  0
# 	Cyclomatic Complexity (ccn):  0
# 	Number of Comments:  1
# 	Extension:  js
# 	Lines of code:  0
# 	Number of functions:  0
# 	Tokens:  0
#
# File Name:  app.js
# 	Average Cyclomatic Complexity (ccn):  1.7666666666666666
# 	Average Lines of code:  13.266666666666667
# 	Average Tokens:  78.83333333333333
# 	Blanks:  81
# 	Cyclomatic Complexity (ccn):  53
# 	Number of Comments:  19
# 	Extension:  js
# 	Lines of code:  381
# 	Number of functions:  30
# 	Tokens:  2406
#
# 	* Analysis cannot be performed for:  assets/icons/centroid.png
#
# 	* Analysis cannot be performed for:  assets/icons/google-maps.png
#
# 	* Analysis cannot be performed for:  assets/icons/map-2.png
#
# 	* Analysis cannot be performed for:  assets/icons/map.png
#
# 	* Analysis cannot be performed for:  assets/icons/marker.png
#
# 	* Analysis cannot be performed for:  assets/style.css
#
# 	* Analysis cannot be performed for:  index.html
#
# ----------------------------------------------------------------------------------------------------
# Commit Message: Add README.md
# 	* Analysis cannot be performed for:  README.md
#
# File Name:  app.js
# 	Average Cyclomatic Complexity (ccn):  1.7666666666666666
# 	Average Lines of code:  13.266666666666667
# 	Average Tokens:  77.9
# 	Blanks:  81
# 	Cyclomatic Complexity (ccn):  53
# 	Number of Comments:  19
# 	Extension:  js
# 	Lines of code:  381
# 	Number of functions:  30
# 	Tokens:  2378
#
# 	* Analysis cannot be performed for:  assets/meetInTheMiddle-2.gif
#
# 	* Analysis cannot be performed for:  assets/meetInTheMiddle.gif
#
# 	* Analysis cannot be performed for:  index.html
#
# ----------------------------------------------------------------------------------------------------
# Commit Message:  add MoboView + fix Recentering single point
# 	* Analysis cannot be performed for:  README.md
#
# File Name:  app.js
# 	Average Cyclomatic Complexity (ccn):  1.7666666666666666
# 	Average Lines of code:  13.266666666666667
# 	Average Tokens:  78.2
# 	Blanks:  83
# 	Cyclomatic Complexity (ccn):  53
# 	Number of Comments:  20
# 	Extension:  js
# 	Lines of code:  381
# 	Number of functions:  30
# 	Tokens:  2388
#
# 	* Analysis cannot be performed for:  assets/meetInTheMiddle-2.gif
#
# ----------------------------------------------------------------------------------------------------
# Commit Message: Add TODO.md + ZoomOut init() mapView
# 	* Analysis cannot be performed for:  MeetMe.html
#
# 	* Analysis cannot be performed for:  README.md
#
# 	* Analysis cannot be performed for:  TODO.md
#
# File Name:  app.js
# 	Average Cyclomatic Complexity (ccn):  1.8387096774193548
# 	Average Lines of code:  13.516129032258064
# 	Average Tokens:  81.29032258064517
# 	Blanks:  93
# 	Cyclomatic Complexity (ccn):  57
# 	Number of Comments:  18
# 	Extension:  js
# 	Lines of code:  401
# 	Number of functions:  31
# 	Tokens:  2561
#
# ----------------------------------------------------------------------------------------------------
# Commit Message:  alert -> logs + fix style
# File Name:  app.js
# 	Average Cyclomatic Complexity (ccn):  1.8
# 	Average Lines of code:  13.166666666666666
# 	Average Tokens:  78.1
# 	Blanks:  87
# 	Cyclomatic Complexity (ccn):  54
# 	Number of Comments:  19
# 	Extension:  js
# 	Lines of code:  378
# 	Number of functions:  30
# 	Tokens:  2384
#
# 	* Analysis cannot be performed for:  assets/style.css
#
# 	* Analysis cannot be performed for:  index.html
#
# ----------------------------------------------------------------------------------------------------
# Commit Message:  test custom midway
# File Name:  app.js
# 	Average Cyclomatic Complexity (ccn):  1.7666666666666666
# 	Average Lines of code:  13.266666666666667
# 	Average Tokens:  78.83333333333333
# 	Blanks:  81
# 	Cyclomatic Complexity (ccn):  53
# 	Number of Comments:  19
# 	Extension:  js
# 	Lines of code:  381
# 	Number of functions:  30
# 	Tokens:  2406
#
# ----------------------------------------------------------------------------------------------------
# Commit Message:  CleanUp debug comments
# File Name:  app.js
# 	Average Cyclomatic Complexity (ccn):  1.8387096774193548
# 	Average Lines of code:  13.64516129032258
# 	Average Tokens:  81.83870967741936
# 	Blanks:  95
# 	Cyclomatic Complexity (ccn):  57
# 	Number of Comments:  18
# 	Extension:  js
# 	Lines of code:  405
# 	Number of functions:  31
# 	Tokens:  2578
#
# ----------------------------------------------------------------------------------------------------
# Commit Message:  Add auto navigator
# 	* Analysis cannot be performed for:  MeetMe.html
#
# 	* Analysis cannot be performed for:  TODO.md
#
# File Name:  app.js
# 	Average Cyclomatic Complexity (ccn):  1.8387096774193548
# 	Average Lines of code:  13.64516129032258
# 	Average Tokens:  81.83870967741936
# 	Blanks:  96
# 	Cyclomatic Complexity (ccn):  57
# 	Number of Comments:  18
# 	Extension:  js
# 	Lines of code:  415
# 	Number of functions:  31
# 	Tokens:  2631
#
# ----------------------------------------------------------------------------------------------------
# Commit Message: Improve grammar for the information message
# File Name:  app.js
# 	Average Cyclomatic Complexity (ccn):  1.7666666666666666
# 	Average Lines of code:  13.133333333333333
# 	Average Tokens:  77.2
# 	Blanks:  81
# 	Cyclomatic Complexity (ccn):  53
# 	Number of Comments:  19
# 	Extension:  js
# 	Lines of code:  377
# 	Number of functions:  30
# 	Tokens:  2357
#
# ----------------------------------------------------------------------------------------------------
# Commit Message: Merge pull request #2 from mehmetseckin/patch-1
#
# Improve grammar for the information message
# File Name:  app.js
# 	Average Cyclomatic Complexity (ccn):  1.7666666666666666
# 	Average Lines of code:  13.133333333333333
# 	Average Tokens:  77.2
# 	Blanks:  81
# 	Cyclomatic Complexity (ccn):  53
# 	Number of Comments:  19
# 	Extension:  js
# 	Lines of code:  377
# 	Number of functions:  30
# 	Tokens:  2357
#
# ----------------------------------------------------------------------------------------------------
# Commit Message:  fix error logging
# 	* Analysis cannot be performed for:  README.md
#
# 	* Analysis cannot be performed for:  TODO.md
#
# File Name:  app.js
# 	Average Cyclomatic Complexity (ccn):  1.8387096774193548
# 	Average Lines of code:  13.64516129032258
# 	Average Tokens:  81.83870967741936
# 	Blanks:  95
# 	Cyclomatic Complexity (ccn):  57
# 	Number of Comments:  18
# 	Extension:  js
# 	Lines of code:  405
# 	Number of functions:  31
# 	Tokens:  2578
#
# ----------------------------------------------------------------------------------------------------
# Commit Message:  Add names on position marker + PH idea.
# 	* Analysis cannot be performed for:  TODO.md
#
# File Name:  app.js
# 	Average Cyclomatic Complexity (ccn):  1.7666666666666666
# 	Average Lines of code:  13.266666666666667
# 	Average Tokens:  78.13333333333334
# 	Blanks:  83
# 	Cyclomatic Complexity (ccn):  53
# 	Number of Comments:  18
# 	Extension:  js
# 	Lines of code:  381
# 	Number of functions:  30
# 	Tokens:  2385
#
# ----------------------------------------------------------------------------------------------------
# Commit Message:  Add twitter handle
# 	* Analysis cannot be performed for:  README.md
#
# File Name:  app.js
# 	Average Cyclomatic Complexity (ccn):  1.7666666666666666
# 	Average Lines of code:  13.266666666666667
# 	Average Tokens:  78.2
# 	Blanks:  83
# 	Cyclomatic Complexity (ccn):  53
# 	Number of Comments:  20
# 	Extension:  js
# 	Lines of code:  381
# 	Number of functions:  30
# 	Tokens:  2388
#
# 	* Analysis cannot be performed for:  index.html
#
# ----------------------------------------------------------------------------------------------------
# Commit Message:  remove redundancy: data exchange
# 	* Analysis cannot be performed for:  TODO.md
#
# File Name:  app.js
# 	Average Cyclomatic Complexity (ccn):  1.8064516129032258
# 	Average Lines of code:  13.35483870967742
# 	Average Tokens:  79.3225806451613
# 	Blanks:  90
# 	Cyclomatic Complexity (ccn):  56
# 	Number of Comments:  18
# 	Extension:  js
# 	Lines of code:  396
# 	Number of functions:  31
# 	Tokens:  2500
#
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# **This concludes Microtask #6: executing Graal via its Python interface using the CoCom Backend.**
